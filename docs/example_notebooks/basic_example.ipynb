# %% [markdown]
# # Basic Example

# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from plottable import ColumnDefinition, Table

# %%
d = pd.DataFrame(np.random.random((5, 5)), columns=["A", "B", "C", "D", "E"]).round(2)

fig, ax = plt.subplots(figsize=(6, 5))

tab = Table(d)

plt.show()

fig.savefig("images/basic_table.png")

# %% [markdown]
# ## Alternating Row Colors

# %%
d = pd.DataFrame(np.random.random((5, 5)), columns=["A", "B", "C", "D", "E"]).round(2)

fig, ax = plt.subplots(figsize=(6, 5))

tab = Table(d, row_dividers=False, odd_row_color="#f2f9fc", even_row_color="#e0f6ff")

plt.show()

fig.savefig("images/alternating_row_color.png")
